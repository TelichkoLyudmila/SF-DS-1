# %% [markdown]
# # Импорт кода по угадыванию числа

# %%
from game_v2 import random_predict #корректный импорт. Также в тексте кода должны быть строчка в конце: if __name__ == '__main__':
from game_v2 import score_game

# %% [markdown]
# обратить внимание, что внизу есть блок с переменными, удобный

# %%
import game_v2 # так импортировать некорректно

# %%
score_game(random_predict)
# Out:
# Количество попыток: 37
# Количество попыток: 75
# Количество попыток: 62
# Количество попыток: 8
# Количество попыток: 14
# Количество попыток: 220
# Количество попыток: 8
# Количество попыток: 84
# Количество попыток: 5
# Количество попыток: 100
# Количество попыток: 3
# Количество попыток: 55
# Количество попыток: 77
# Количество попыток: 53
# Количество попыток: 10
# Количество попыток: 154
# Количество попыток: 6
# Количество попыток: 114
# Количество попыток: 152
# Количество попыток: 77
# Количество попыток: 84
# Количество попыток: 72
# Количество попыток: 35
# Количество попыток: 31
# Количество попыток: 18
# Количество попыток: 72
# Количество попыток: 74
# Количество попыток: 70
# Количество попыток: 19
# Количество попыток: 35
# Количество попыток: 32
# Количество попыток: 41
# Количество попыток: 6
# Количество попыток: 167
# Количество попыток: 164
# Количество попыток: 28
# Количество попыток: 27
# Количество попыток: 36
# Количество попыток: 25
# ...
